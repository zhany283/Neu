# %%
import os
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", RuntimeWarning)

# %%
import h5py

# %%
adatas = [x for x in os.listdir('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/data/') if x.endswith('cleaned.h5ad')]

# %%
adatas
# Out:
# ['2054_00_cleaned.h5ad',
#  '2060_41_cleaned.h5ad',
#  '2070_00_cleaned.h5ad',
#  '2072_00_cleaned.h5ad',
#  '2074_00_cleaned.h5ad',
#  '2075_00_cleaned.h5ad',
#  '2094_01_cleaned.h5ad',
#  'S14_00_cleaned.h5ad',
#  'S15_00_cleaned.h5ad',
#  'S16_00_cleaned.h5ad',
#  'S17_00_cleaned.h5ad']

# %%
def load_it(adata):
    samp = adata.split('_')[0]
    days = adata.split('_')[1]
    adata = sc.read_h5ad('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/data/' + adata)
    adata.obs['Patient'] = samp
    adata.obs['Days'] = days
    adata.obs['Sample'] = adata.obs['Patient'] + '_' + adata.obs['Days']
    adata.obs.index = adata.obs.index + '-' + samp + '_' + days
    return adata

# %%
adatas = [load_it(ad) for ad in adatas]

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 4484 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 2933 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 3689 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 5996 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 5620 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 3047 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 5243 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 6905 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 6142 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 6173 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features',
#  AnnData object with n_obs × n_vars = 4627 × 37143
#      obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_RNA3', 'nFeature_RNA3', 'Patient', 'Days', 'Sample'
#      var: 'features']

# %%
def qc(adata):
    sc.pp.filter_cells(adata, min_genes = 10)
    adata.var["mt"] = adata.var_names.str.startswith("MT-")
    adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL"))
    adata.var["hb"] = adata.var_names.str.contains(("^HB[^(P)]"))
    sc.pp.calculate_qc_metrics(adata, qc_vars=["mt", "ribo", "hb"], inplace=True, percent_top=[20], log1p=True)
    
    remove = ['total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo', 
          'log1p_total_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'nCount_RNA3', 'nFeature_RNA3', 'orig.ident', 'nCount_RNA', 'nFeature_RNA']
    adata.obs = adata.obs[[x for x in adata.obs.columns if x not in remove]]
    return adata

# %%
adatas = [qc(ad) for ad in adatas]

# %%
df = pd.concat([x.obs for x in adatas])

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 4287 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 2177 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 3520 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5660 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5134 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 2873 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5094 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 6670 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5894 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5808 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 4345 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts']

# %%
print(df)
# Out:
#                                    Patient Days   Sample  n_genes  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00    2054   00  2054_00       45
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00    2054   00  2054_00       54
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00    2054   00  2054_00       49
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00    2054   00  2054_00       90
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00    2054   00  2054_00       54
# ...                                    ...  ...      ...      ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00      S17   00   S17_00      383
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00      S17   00   S17_00       38
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00      S17   00   S17_00      378
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00      S17   00   S17_00       41
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00      S17   00   S17_00      183
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00                    11.546841       0.000000
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00                    57.142857       0.000000
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00                    13.333333       0.222222
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00                    54.347826       0.000000
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00                    22.009569       0.478469
#
#                                     pct_counts_ribo  pct_counts_hb
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00              0.0            0.0
# ...                                             ...            ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00               0.0            0.0
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00               0.0            0.0
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00               0.0            0.0
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00               0.0            0.0
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00               0.0            0.0
#
# [51462 rows x 12 columns]

# %%
df = df.sort_values('Sample')

# %%
#value = "pct_counts_mt"
#value = "n_genes"
#value = 'pct_counts_in_top_20_genes'
value = "log1p_total_counts"

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

g = sns.FacetGrid(df, row="Sample", hue="Sample", aspect=15, height=0.5, palette="tab20")

g.map(sns.kdeplot, value, clip_on=False, fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, value, clip_on=False, color="w", lw=2)

g.map(plt.axhline, y=0, lw=2, clip_on=False)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, value)

g.figure.subplots_adjust(hspace=-.6)

g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True)

for ax in g.axes.flat:
    ax.axvline(x=df[value].median(), color='r', linestyle='-')


plt.show()

# %%
value = "pct_counts_mt"
#value = "n_genes"
#value = 'pct_counts_in_top_20_genes'
#value = "log1p_total_counts"
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

g = sns.FacetGrid(df, row="Sample", hue="Sample", aspect=15, height=0.5, palette="tab20")

g.map(sns.kdeplot, value, clip_on=False, fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, value, clip_on=False, color="w", lw=2)

g.map(plt.axhline, y=0, lw=2, clip_on=False)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, value)

g.figure.subplots_adjust(hspace=-.6)

g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True)

for ax in g.axes.flat:
    ax.axvline(x=df[value].median(), color='r', linestyle='-')


plt.show()

# %%
#value = "pct_counts_mt"
value = "n_genes"
#value = 'pct_counts_in_top_20_genes'
#value = "log1p_total_counts"

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

g = sns.FacetGrid(df, row="Sample", hue="Sample", aspect=15, height=0.5, palette="tab20")

g.map(sns.kdeplot, value, clip_on=False, fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, value, clip_on=False, color="w", lw=2)

g.map(plt.axhline, y=0, lw=2, clip_on=False)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, value)

g.figure.subplots_adjust(hspace=-.6)

g.set_titles("")
g.set(yticks=[], ylabel="")
g.set(xlim=(0, 200))
g.despine(bottom=True, left=True)

for ax in g.axes.flat:
    ax.axvline(x=df[value].median(), color='r', linestyle='-')


plt.show()

# %%
#value = "pct_counts_mt"
#value = "n_genes"
value = 'pct_counts_in_top_20_genes'
#value = "log1p_total_counts"

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

g = sns.FacetGrid(df, row="Sample", hue="Sample", aspect=15, height=0.5, palette="tab20")

g.map(sns.kdeplot, value, clip_on=False, fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, value, clip_on=False, color="w", lw=2)

g.map(plt.axhline, y=0, lw=2, clip_on=False)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, value)

g.figure.subplots_adjust(hspace=-.6)

g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True)

for ax in g.axes.flat:
    ax.axvline(x=df[value].median(), color='r', linestyle='-')


plt.show()

# %%
df
# Out:
#                                    Patient Days   Sample  n_genes  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00    2054   00  2054_00       45
# GGGATATTCCTGAGGAAGTGAGTG-1-2054_00    2054   00  2054_00       87
# GGGATATTCGGTACCTAGTGAGTG-1-2054_00    2054   00  2054_00       41
# GGGATATTCTCCATCTAGTGAGTG-1-2054_00    2054   00  2054_00      242
# GGGATATTCTTGAATCAGTGAGTG-1-2054_00    2054   00  2054_00      298
# ...                                    ...  ...      ...      ...
# CCGCATTAGTGATGGTATGTTGAC-1-S17_00      S17   00   S17_00       70
# CCGCCATCAAATAGGAATGTTGAC-1-S17_00      S17   00   S17_00      244
# CCGCCATCAAGGCCATATGTTGAC-1-S17_00      S17   00   S17_00       17
# CCCTTGCTCCCACATAATGTTGAC-1-S17_00      S17   00   S17_00       16
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00      S17   00   S17_00      183
#
#                                     n_genes_by_counts  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00                 45
# GGGATATTCCTGAGGAAGTGAGTG-1-2054_00                 87
# GGGATATTCGGTACCTAGTGAGTG-1-2054_00                 41
# GGGATATTCTCCATCTAGTGAGTG-1-2054_00                242
# GGGATATTCTTGAATCAGTGAGTG-1-2054_00                298
# ...                                               ...
# CCGCATTAGTGATGGTATGTTGAC-1-S17_00                  70
# CCGCCATCAAATAGGAATGTTGAC-1-S17_00                 244
# CCGCCATCAAGGCCATATGTTGAC-1-S17_00                  17
# CCCTTGCTCCCACATAATGTTGAC-1-S17_00                  16
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00                 183
#
#                                     log1p_n_genes_by_counts  total_counts  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00                 3.828641          49.0
# GGGATATTCCTGAGGAAGTGAGTG-1-2054_00                 4.477337         100.0
# GGGATATTCGGTACCTAGTGAGTG-1-2054_00                 3.737670          44.0
# GGGATATTCTCCATCTAGTGAGTG-1-2054_00                 5.493061         349.0
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scvi

# %%
#!pip install celltypist scvi-tools hyperopt "ray[tune]" anndata2ri

# %%
import warnings
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", RuntimeWarning)

# %%
import celltypist
from celltypist import models

# %%
#models.get_all_models()

# %%
import os
import scanpy as sc
import pandas as pd

rdatas = []
for dem in [x for x in os.listdir('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/ref_data/') if 'dem' in x]:
    basename = dem.split('.')[0]
    samp = basename.split('_')[1]  # Extract the sample part (e.g., "AML1012-D0")

    # Debugging output
    print(f"Processing DEM file: {dem}")
    print(f"Extracted sample: {samp}")

    # Find the corresponding annotation file
    anno_files = [x for x in os.listdir('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/ref_data/') if samp in x and 'anno' in x]
    
    if anno_files:
        anno = anno_files[0]  # Use the first match
        print(f"Found annotation file: {anno}")
    else:
        print(f"No annotation file found for sample: {samp}")
        continue  # Skip this iteration if no annotation file is found

    # Load the DEM data and annotation
    temp_data = sc.read_text('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/ref_data/' + dem).T
    temp_anno = pd.read_table('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/ref_data/' + anno, index_col=0)[['CellType']]

    # Merge the annotation data with the DEM data
    temp_data.obs = temp_data.obs.merge(right=temp_anno, left_index=True, right_index=True)

    # Add the ID (basename) to the obs data
    temp_data.obs['ID'] = basename

    # Append to rdatas
    rdatas.append(temp_data)
# Out:
# Processing DEM file: GSM3587923_AML1012-D0.dem.txt.gz
# Extracted sample: AML1012-D0
# Found annotation file: GSM3587924_AML1012-D0.anno.txt.gz
# Processing DEM file: GSM3587925_AML210A-D0.dem.txt.gz
# Extracted sample: AML210A-D0
# Found annotation file: GSM3587926_AML210A-D0.anno.txt.gz
# Processing DEM file: GSM3587927_AML314-D0.dem.txt.gz
# Extracted sample: AML314-D0
# Found annotation file: GSM3587928_AML314-D0.anno.txt.gz
# Processing DEM file: GSM3587929_AML314-D31.dem.txt.gz
# Extracted sample: AML314-D31
# Found annotation file: GSM3587930_AML314-D31.anno.txt.gz
# Processing DEM file: GSM3587931_AML328-D0.dem.txt.gz
# Extracted sample: AML328-D0
# Found annotation file: GSM3587932_AML328-D0.anno.txt.gz
# Processing DEM file: GSM3587933_AML328-D113.dem.txt.gz
# Extracted sample: AML328-D113
# Found annotation file: GSM3587934_AML328-D113.anno.txt.gz
# Processing DEM file: GSM3587935_AML328-D171.dem.txt.gz
# Extracted sample: AML328-D171
# Found annotation file: GSM3587936_AML328-D171.anno.txt.gz
# Processing DEM file: GSM3587937_AML328-D29.dem.txt.gz
# Extracted sample: AML328-D29
# Found annotation file: GSM3587938_AML328-D29.anno.txt.gz
# Processing DEM file: GSM3587940_AML329-D0.dem.txt.gz
# Extracted sample: AML329-D0
# Found annotation file: GSM3587941_AML329-D0.anno.txt.gz
# Processing DEM file: GSM3587942_AML329-D20.dem.txt.gz
# Extracted sample: AML329-D20
# Found annotation file: GSM3587943_AML329-D20.anno.txt.gz
# Processing DEM file: GSM3587944_AML329-D37.dem.txt.gz
# Extracted sample: AML329-D37
# Found annotation file: GSM3587945_AML329-D37.anno.txt.gz
# Processing DEM file: GSM3587946_AML371-D0.dem.txt.gz
# Extracted sample: AML371-D0
# Found annotation file: GSM3587947_AML371-D0.anno.txt.gz
# Processing DEM file: GSM3587948_AML371-D34.dem.txt.gz
# Extracted sample: AML371-D34
# Found annotation file: GSM3587949_AML371-D34.anno.txt.gz
# Processing DEM file: GSM3587950_AML419A-D0.dem.txt.gz
# Extracted sample: AML419A-D0
# Found annotation file: GSM3587951_AML419A-D0.anno.txt.gz
# Processing DEM file: GSM3587953_AML420B-D0.dem.txt.gz
# Extracted sample: AML420B-D0
# Found annotation file: GSM3587954_AML420B-D0.anno.txt.gz
# Processing DEM file: GSM3587955_AML420B-D14.dem.txt.gz
# Extracted sample: AML420B-D14
# Found annotation file: GSM3587956_AML420B-D14.anno.txt.gz
# Processing DEM file: GSM3587957_AML420B-D35.dem.txt.gz
# Extracted sample: AML420B-D35
# Found annotation file: GSM3587958_AML420B-D35.anno.txt.gz
# Processing DEM file: GSM3587959_AML475-D0.dem.txt.gz
# Extracted sample: AML475-D0
# Found annotation file: GSM3587960_AML475-D0.anno.txt.gz
# Processing DEM file: GSM3587961_AML475-D29.dem.txt.gz
# Extracted sample: AML475-D29
# Found annotation file: GSM3587962_AML475-D29.anno.txt.gz
# Processing DEM file: GSM3587963_AML556-D0.dem.txt.gz
# Extracted sample: AML556-D0
# Found annotation file: GSM3587964_AML556-D0.anno.txt.gz
# Processing DEM file: GSM3587965_AML556-D15.dem.txt.gz
# Extracted sample: AML556-D15
# Found annotation file: GSM3587966_AML556-D15.anno.txt.gz
# Processing DEM file: GSM3587967_AML556-D31.dem.txt.gz
# Extracted sample: AML556-D31
# Found annotation file: GSM3587968_AML556-D31.anno.txt.gz
# Processing DEM file: GSM3587969_AML707B-D0.dem.txt.gz
# Extracted sample: AML707B-D0
# Found annotation file: GSM3587970_AML707B-D0.anno.txt.gz
# Processing DEM file: GSM3587971_AML707B-D113.dem.txt.gz
# Extracted sample: AML707B-D113
# Found annotation file: GSM3587972_AML707B-D113.anno.txt.gz
# Processing DEM file: GSM3587973_AML707B-D18.dem.txt.gz
# Extracted sample: AML707B-D18
# Found annotation file: GSM3587974_AML707B-D18.anno.txt.gz
# Processing DEM file: GSM3587975_AML707B-D41.dem.txt.gz
# Extracted sample: AML707B-D41
# Found annotation file: GSM3587976_AML707B-D41.anno.txt.gz
# Processing DEM file: GSM3587977_AML707B-D97.dem.txt.gz
# Extracted sample: AML707B-D97
# Found annotation file: GSM3587978_AML707B-D97.anno.txt.gz
# Processing DEM file: GSM3587980_AML722B-D0.dem.txt.gz
# Extracted sample: AML722B-D0
# Found annotation file: GSM3587981_AML722B-D0.anno.txt.gz
# Processing DEM file: GSM3587982_AML722B-D49.dem.txt.gz
# Extracted sample: AML722B-D49
# Found annotation file: GSM3587983_AML722B-D49.anno.txt.gz
# Processing DEM file: GSM3587984_AML870-D0.dem.txt.gz
# Extracted sample: AML870-D0
# Found annotation file: GSM3587985_AML870-D0.anno.txt.gz
# Processing DEM file: GSM3587986_AML870-D14.dem.txt.gz
# Extracted sample: AML870-D14
# Found annotation file: GSM3587987_AML870-D14.anno.txt.gz
# Processing DEM file: GSM3587988_AML916-D0.dem.txt.gz
# Extracted sample: AML916-D0
# Found annotation file: GSM3587989_AML916-D0.anno.txt.gz
# Processing DEM file: GSM3587990_AML921A-D0.dem.txt.gz
# Extracted sample: AML921A-D0
# Found annotation file: GSM3587991_AML921A-D0.anno.txt.gz
# Processing DEM file: GSM3587992_AML997-D0.dem.txt.gz
# Extracted sample: AML997-D0
# Found annotation file: GSM3587993_AML997-D0.anno.txt.gz
# Processing DEM file: GSM3587994_AML997-D35.dem.txt.gz
# Extracted sample: AML997-D35
# Found annotation file: GSM3587995_AML997-D35.anno.txt.gz
# Processing DEM file: GSM3587996_BM1.dem.txt.gz
# Extracted sample: BM1
# Found annotation file: GSM3587996_BM1.anno.txt.gz
# Processing DEM file: GSM3587997_BM2.dem.txt.gz
# Extracted sample: BM2
# Found annotation file: GSM3587997_BM2.anno.txt.gz
# Processing DEM file: GSM3587998_BM3.dem.txt.gz
# Extracted sample: BM3
# Found annotation file: GSM3587999_BM3.anno.txt.gz
# Processing DEM file: GSM3588000_BM4.dem.txt.gz
# Extracted sample: BM4
# Found annotation file: GSM3588001_BM4.anno.txt.gz
# Processing DEM file: GSM3588002_BM5-34p.dem.txt.gz
# Extracted sample: BM5-34p
# Found annotation file: GSM3588002_BM5-34p.anno.txt.gz
# Processing DEM file: GSM3588003_BM5-34p38n.dem.txt.gz
# Extracted sample: BM5-34p38n
# Found annotation file: GSM3588003_BM5-34p38n.anno.txt.gz
# Processing DEM file: GSM3588004_MUTZ3.dem.txt.gz
# Extracted sample: MUTZ3
# Found annotation file: GSM3588004_MUTZ3.anno.txt.gz
# Processing DEM file: GSM3588005_OCI-AML3.dem.txt.gz
# Extracted sample: OCI-AML3
# Found annotation file: GSM3588005_OCI-AML3.anno.txt.gz

# %%
for i, data in enumerate(rdatas):
    print(f"Data for sample {i}:")
    print(data)
# Out:
# Data for sample 0:
# AnnData object with n_obs × n_vars = 1136 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 1:
# AnnData object with n_obs × n_vars = 748 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 2:
# AnnData object with n_obs × n_vars = 162 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 3:
# AnnData object with n_obs × n_vars = 346 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 4:
# AnnData object with n_obs × n_vars = 1094 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 5:
# AnnData object with n_obs × n_vars = 2029 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 6:
# AnnData object with n_obs × n_vars = 1402 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 7:
# AnnData object with n_obs × n_vars = 1880 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 8:
# AnnData object with n_obs × n_vars = 525 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 9:
# AnnData object with n_obs × n_vars = 953 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 10:
# AnnData object with n_obs × n_vars = 224 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 11:
# AnnData object with n_obs × n_vars = 756 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 12:
# AnnData object with n_obs × n_vars = 204 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 13:
# AnnData object with n_obs × n_vars = 1189 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 14:
# AnnData object with n_obs × n_vars = 485 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 15:
# AnnData object with n_obs × n_vars = 1282 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 16:
# AnnData object with n_obs × n_vars = 743 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 17:
# AnnData object with n_obs × n_vars = 423 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 18:
# AnnData object with n_obs × n_vars = 102 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 19:
# AnnData object with n_obs × n_vars = 2328 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 20:
# AnnData object with n_obs × n_vars = 1203 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 21:
# AnnData object with n_obs × n_vars = 1451 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 22:
# AnnData object with n_obs × n_vars = 1586 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 23:
# AnnData object with n_obs × n_vars = 708 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 24:
# AnnData object with n_obs × n_vars = 1673 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 25:
# AnnData object with n_obs × n_vars = 387 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 26:
# AnnData object with n_obs × n_vars = 84 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 27:
# AnnData object with n_obs × n_vars = 79 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 28:
# AnnData object with n_obs × n_vars = 73 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 29:
# AnnData object with n_obs × n_vars = 345 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 30:
# AnnData object with n_obs × n_vars = 96 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 31:
# AnnData object with n_obs × n_vars = 933 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 32:
# AnnData object with n_obs × n_vars = 3813 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 33:
# AnnData object with n_obs × n_vars = 83 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 34:
# AnnData object with n_obs × n_vars = 187 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 35:
# AnnData object with n_obs × n_vars = 108 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 36:
# AnnData object with n_obs × n_vars = 188 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 37:
# AnnData object with n_obs × n_vars = 643 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 38:
# AnnData object with n_obs × n_vars = 3738 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 39:
# AnnData object with n_obs × n_vars = 1431 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 40:
# AnnData object with n_obs × n_vars = 1590 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 41:
# AnnData object with n_obs × n_vars = 1502 × 27899
#     obs: 'CellType', 'ID'
# Data for sample 42:
# AnnData object with n_obs × n_vars = 1178 × 27899
#     obs: 'CellType', 'ID'

# %%
rdata = sc.concat(rdatas)

# %%
rdata.obs.groupby('CellType').size()
# Out:
# CellType
# B                520
# CTL             1338
# GMP              918
# GMP-like        3055
# HSC             1709
# HSC-like        1979
# Mono            2758
# Mono-like       2655
# NK              1969
# Plasma          1146
# ProB             298
# ProMono         1146
# ProMono-like    1917
# Prog            1709
# Prog-like       4438
# T               7105
# cDC              849
# cDC-like        2125
# earlyEry        1119
# lateEry         1329
# pDC              225
# dtype: int64

# %%
sc.pp.filter_genes(rdata, min_cells = 10)

# %%
sc.pp.normalize_total(rdata, target_sum = 1e4) #Note this is only for cell annotation, recommended by authors but not best
sc.pp.log1p(rdata)

# %%
rdata.obs
# Out:
#                              CellType                     ID
# AML1012-D0_AAAAAGTTACGT           GMP  GSM3587923_AML1012-D0
# AML1012-D0_AAAACACCAATC      GMP-like  GSM3587923_AML1012-D0
# AML1012-D0_AAAATAGCCTTT     Prog-like  GSM3587923_AML1012-D0
# AML1012-D0_AAACATTAAACG  ProMono-like  GSM3587923_AML1012-D0
# AML1012-D0_AAACCACGTGCN     Prog-like  GSM3587923_AML1012-D0
# ...                               ...                    ...
# OCI-AML3_TTTGAGCCAACC        GMP-like    GSM3588005_OCI-AML3
# OCI-AML3_TTTGCCACAGGC    ProMono-like    GSM3588005_OCI-AML3
# OCI-AML3_TTTTATGAATTN        GMP-like    GSM3588005_OCI-AML3
# OCI-AML3_TTTTGACTTTTN        GMP-like    GSM3588005_OCI-AML3
# OCI-AML3_TTTTGTGACCGT        GMP-like    GSM3588005_OCI-AML3
#
# [41090 rows x 2 columns]

# %%
rdata = rdata[~rdata.obs.CellType.isna()]

# %%
rdata
# Out:
# View of AnnData object with n_obs × n_vars = 40307 × 19616
#     obs: 'CellType', 'ID'
#     var: 'n_cells'
#     uns: 'log1p'

# %%
#ref_model = celltypist.train(rdata, labels = 'CellType', n_jobs = 22,
#                            use_SGD = False,
#                            feature_selection = True, top_genes = 300)

# %%
#ref_model.write('/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/ref_data/models/ref.pkl')

# %%
ref_model = models.Model.load(model="/mnt/c/Users/ethan/OneDrive/桌面/sc1186deepseq/ref_data/models/ref.pkl")

# %%
model_low = models.Model.load(model="Immune_All_Low.pkl")

# %%
def predict_cells(adata):
    sc.pp.filter_genes(adata, min_cells = 10)
    sc.pp.normalize_total(adata, target_sum=1e4) #not recommended for typical pp
    sc.pp.log1p(adata)

    adata.X = adata.X.toarray()

    predictions = celltypist.annotate(adata, model=model_low, majority_voting=False)
    predictions_adata = predictions.to_adata()
    adata.obs["low_label"] = predictions_adata.obs.loc[adata.obs.index, "predicted_labels"]
    adata.obs["low_score"] = predictions_adata.obs.loc[adata.obs.index, "conf_score"]

    predictions = celltypist.annotate(adata, model=ref_model, majority_voting=False)
    predictions_adata = predictions.to_adata()
    adata.obs["ref_label"] = predictions_adata.obs.loc[adata.obs.index, "predicted_labels"]
    adata.obs["ref_score"] = predictions_adata.obs.loc[adata.obs.index, "conf_score"]

    return adata.obs

# %%
#adatas = [sc.read_h5ad('pp_adata/' + x) for x in os.listdir('pp_adata')]

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 4287 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 2177 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 3520 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5660 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5134 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 2873 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5094 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 6670 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5894 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 5808 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 4345 × 37143
#      obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'
#      var: 'features', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts']

# %%
len(adatas)
# Out:
# 11

# %%
predictions = [predict_cells(ad.copy()) for ad in adatas]
# Out:
# 🔬 Input data has 4287 cells and 6152 genes
# 🔗 Matching reference genes in the model
# 🧬 2298 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4287 cells and 6152 genes
# 🔗 Matching reference genes in the model
# 🧬 1337 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2177 cells and 1424 genes
# 🔗 Matching reference genes in the model
# 🧬 714 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2177 cells and 1424 genes
# 🔗 Matching reference genes in the model
# 🧬 471 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3520 cells and 5944 genes
# 🔗 Matching reference genes in the model
# 🧬 2239 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3520 cells and 5944 genes
# 🔗 Matching reference genes in the model
# 🧬 1319 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5660 cells and 5687 genes
# 🔗 Matching reference genes in the model
# 🧬 2080 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5660 cells and 5687 genes
# 🔗 Matching reference genes in the model
# 🧬 1216 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5134 cells and 7758 genes
# 🔗 Matching reference genes in the model
# 🧬 2729 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5134 cells and 7758 genes
# 🔗 Matching reference genes in the model
# 🧬 1507 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2873 cells and 3018 genes
# 🔗 Matching reference genes in the model
# 🧬 1296 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2873 cells and 3018 genes
# 🔗 Matching reference genes in the model
# 🧬 817 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5094 cells and 5967 genes
# 🔗 Matching reference genes in the model
# 🧬 2217 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5094 cells and 5967 genes
# 🔗 Matching reference genes in the model
# 🧬 1276 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6670 cells and 7385 genes
# 🔗 Matching reference genes in the model
# 🧬 2549 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6670 cells and 7385 genes
# 🔗 Matching reference genes in the model
# 🧬 1452 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5894 cells and 6984 genes
# 🔗 Matching reference genes in the model
# 🧬 2465 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5894 cells and 6984 genes
# 🔗 Matching reference genes in the model
# 🧬 1418 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5808 cells and 8316 genes
# 🔗 Matching reference genes in the model
# 🧬 2838 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5808 cells and 8316 genes
# 🔗 Matching reference genes in the model
# 🧬 1564 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4345 cells and 7390 genes
# 🔗 Matching reference genes in the model
# 🧬 2588 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4345 cells and 7390 genes
# 🔗 Matching reference genes in the model
# 🧬 1470 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!

# %%
predictions = pd.concat(predictions)[['low_label', 'low_score', 'ref_label', 'ref_score']]

predictions
# Out:
#                                                    low_label  low_score  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00      Alveolar macrophages   0.033422
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00            Memory B cells   0.069340
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00  Tcm/Naive helper T cells   0.578305
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00  Tcm/Naive helper T cells   0.688201
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00       Classical monocytes   0.023848
# ...                                                      ...        ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00   Tcm/Naive helper T cells   0.135763
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00        Classical monocytes   0.274351
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00                   NK cells   0.064383
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00   Tcm/Naive helper T cells   0.136261
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00   Tcm/Naive helper T cells   0.037311
#
#                                     ref_label  ref_score
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00        HSC   0.959079
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00  Prog-like   0.006366
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00        HSC   0.000890
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00       Mono   0.968169
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00       Mono   0.999997
# ...                                       ...        ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00           T   0.998427
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00   Mono-like   0.220773
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00          NK   0.998342
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00   Prog-like   0.001025
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00           T   0.002089
#
# [51462 rows x 4 columns]

# %%
adata = sc.concat(adatas)

# %%
predictions.to_csv('PREDICTIONS.csv')

# %%
import pandas as pd

predictions = pd.read_csv('PREDICTIONS.csv', index_col=0)  # Make sure to use the correct index column


# Add both 'low_label' and 'low_score' to adata.obs
adata.obs['low_label'] = predictions['low_label']
adata.obs['low_score'] = predictions['low_score']
adata.obs['ref_label'] = predictions['ref_label']
adata.obs['ref_score'] = predictions['ref_score']

# %%
print(predictions.columns)
# Out:
# Index(['low_label', 'low_score', 'ref_label', 'ref_score'], dtype='object')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 51462 × 37143
#     obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'low_label', 'low_score', 'ref_label', 'ref_score'

# %%
adata.obs
# Out:
#                                    Patient Days   Sample  n_genes  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00    2054   00  2054_00       45
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00    2054   00  2054_00       54
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00    2054   00  2054_00       49
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00    2054   00  2054_00       90
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00    2054   00  2054_00       54
# ...                                    ...  ...      ...      ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00      S17   00   S17_00      383
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00      S17   00   S17_00       38
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00      S17   00   S17_00      378
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00      S17   00   S17_00       41
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00      S17   00   S17_00      183
#
#                                     n_genes_by_counts  \
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00                    57.142857       0.000000
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00                    13.333333       0.222222
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00                    54.347826       0.000000
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00                    22.009569       0.478469
#
#                                     pct_counts_ribo  pct_counts_hb  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00              0.0            0.0
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00              0.0            0.0
# ...                                             ...            ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00               0.0            0.0
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00               0.0            0.0
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00               0.0            0.0
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00               0.0            0.0
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00               0.0            0.0
#
#                                                    low_label  low_score  \
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00      Alveolar macrophages   0.033422
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00            Memory B cells   0.069340
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00  Tcm/Naive helper T cells   0.578305
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00  Tcm/Naive helper T cells   0.688201
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00       Classical monocytes   0.023848
# ...                                                      ...        ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00   Tcm/Naive helper T cells   0.135763
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00        Classical monocytes   0.274351
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00                   NK cells   0.064383
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00   Tcm/Naive helper T cells   0.136261
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00   Tcm/Naive helper T cells   0.037311
#
#                                     ref_label  ref_score
# AAACAAGCATTTGGAGAGTGAGTG-1-2054_00        HSC   0.959079
# AAACCAATCGCTTGACAGTGAGTG-1-2054_00  Prog-like   0.006366
# AAACCAATCGGGCAGTAGTGAGTG-1-2054_00        HSC   0.000890
# AAACCAGGTGCTGATTAGTGAGTG-1-2054_00       Mono   0.968169
# AAACCAGGTTCTCAAAAGTGAGTG-1-2054_00       Mono   0.999997
# ...                                       ...        ...
# TTTGGCGGTGGGTGTGATGTTGAC-1-S17_00           T   0.998427
# TTTGGCGGTTCCTTTGATGTTGAC-1-S17_00   Mono-like   0.220773
# TTTGTGAGTAATTGCCATGTTGAC-1-S17_00          NK   0.998342
# TTTGTGAGTGGTTAAGATGTTGAC-1-S17_00   Prog-like   0.001025
# TTTGTGAGTGGTTCTGATGTTGAC-1-S17_00           T   0.002089
#
# [51462 rows x 16 columns]

# %% [markdown]
# scVI label transfer

# %% [markdown]
# to be added...

# %% [markdown]
# Integration

# %%
from scvi.autotune import ModelTuner
from ray import tune

# %%
sc.pp.filter_genes(adata, min_cells = 50)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 51462 × 8705
#     obs: 'Patient', 'Days', 'Sample', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'low_label', 'low_score', 'ref_label', 'ref_score'
#     var: 'n_cells'

# %%
model_cls = scvi.model.SCVI
model_cls.setup_anndata(adata, categorical_covariate_keys = ['Sample'],
                             continuous_covariate_keys=['pct_counts_mt', 'pct_counts_ribo'])

tuner = ModelTuner(model_cls)
# Out:
# Unable to initialize backend 'cuda':
# Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
#!pip install --upgrade "jax[cuda11_cudnn82]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

# %%
tuner.info()
# Out:
# ModelTuner registry for SCVI
#                   Tunable hyperparameters
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃      Hyperparameter      ┃ Default value ┃    Source    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │         n_hidden         │      128      │     VAE      │
# │         n_latent         │      10       │     VAE      │
# │         n_layers         │       1       │     VAE      │
# │       dropout_rate       │      0.1      │     VAE      │
# │        dispersion        │     gene      │     VAE      │
# │     log_variational      │     True      │     VAE      │
# │     gene_likelihood      │     zinb      │     VAE      │
# │   latent_distribution    │    normal     │     VAE      │
# │    encode_covariates     │     False     │     VAE      │
# │ deeply_inject_covariates │     True      │     VAE      │
# │      use_batch_norm      │     both      │     VAE      │
# │      use_layer_norm      │     none      │     VAE      │
# │  use_observed_lib_size   │     True      │     VAE      │
# │      var_activation      │     None      │     VAE      │
# │        optimizer         │     Adam      │ TrainingPlan │
# │            lr            │     0.001     │ TrainingPlan │
# │       weight_decay       │     1e-06     │ TrainingPlan │
# │           eps            │     0.01      │ TrainingPlan │
# │    n_steps_kl_warmup     │     None      │ TrainingPlan │
# │    n_epochs_kl_warmup    │      400      │ TrainingPlan │
# │   reduce_lr_on_plateau   │     False     │ TrainingPlan │
# │        lr_factor         │      0.6      │ TrainingPlan │
# │       lr_patience        │      30       │ TrainingPlan │
# │       lr_threshold       │      0.0      │ TrainingPlan │
# │          lr_min          │       0       │ TrainingPlan │
# │      max_kl_weight       │      1.0      │ TrainingPlan │
# │      min_kl_weight       │      0.0      │ TrainingPlan │
# │        batch_size        │      128      │     SCVI     │
# └──────────────────────────┴───────────────┴──────────────┘
#        Available metrics
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃     Metric      ┃    Mode    ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ validation_loss │    min     │
# └─────────────────┴────────────┘
#                          Default search space
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Hyperparameter ┃ Sample function ┃  Arguments  ┃ Keyword arguments ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │    n_hidden    │     choice      │ [[64, 128]] │        {}         │
# └────────────────┴─────────────────┴─────────────┴───────────────────┘

# %%
search_space = {
    "n_hidden": tune.choice([92, 128, 192, 256]),
    "n_latent": tune.choice([10, 20, 30, 40, 50, 60]),
    "n_layers": tune.choice([1, 2, 3]),
    "lr": tune.loguniform(1e-4, 1e-2),
    "gene_likelihood": tune.choice(["nb", "zinb"])}

# %%
results = tuner.fit(adata, metric="validation_loss",
                    #resources = {'gpu': 1}, #have to specify gpu or might not use
                    search_space = search_space,
                   num_samples = 100,
                   max_epochs = 20)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024
-- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-09-17 01:58:09,288	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/zyu2632/scneu/scvi_log/autotune/2024-09-16_23-34-45_scvi' in 0.0155s.
# 2024-09-17 01:58:09,304	INFO tune.py:1041 -- Total run time: 8604.06 seconds (8604.01 seconds for the tuning loop).

# %%
best_vl = 10000
best_i = 0
for i, res in enumerate(results.results):
    vl = res.metrics['validation_loss']

    if vl < best_vl:
        best_vl = vl
        best_i = i

# %%
best_vl
# Out:
# 397.175537109375

# %%
results.results[best_i]
# Out:
# Result(
#   metrics={'validation_loss': 397.175537109375},
#   path='/home/zyu2632/scneu/scvi_log/autotune/2024-09-16_23-34-45_scvi/_trainable_4789bc0e_16_gene_likelihood=zinb,lr=0.0009,n_hidden=128,n_latent=60,n_layers=1_2024-09-16_23-39-29',
#   filesystem='local',
#   checkpoint=None
# )

# %%
scvi.model.SCVI.setup_anndata(adata,
                              categorical_covariate_keys = ['Sample'],
                             continuous_covariate_keys=['pct_counts_mt', 'pct_counts_ribo'])

# %%
model = scvi.model.SCVI(adata, n_hidden = 128, n_latent = 60, n_layers = 1, gene_likelihood = 'zinb',dropout_rate=0.1)

# %%
kwargs = {'lr': 0.0009}

# %%
model.train(max_epochs = 200, early_stopping = True, plan_kwargs = kwargs)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 35/200:  17%|██▋             | 34/200 [02:39<13:08,  4.75s/it, v_num=1, train_loss_step=191, train_loss_epoch=183]

# %%
model.save('the_model')

# %%
model = scvi.model.SCVI.load('the_model/', adata)
# Out:
# INFO     File the_model/model.pt already downloaded

# %%
y = model.history['reconstruction_loss_validation']['reconstruction_loss_validation'].min()

# %%
plt.plot(model.history['reconstruction_loss_train']['reconstruction_loss_train'], label='train')
plt.plot(model.history['reconstruction_loss_validation']['reconstruction_loss_validation'], label='validation')

plt.axhline(y, c = 'k')

plt.legend()
plt.show()

# %%
adata.write_h5ad('temp.h5ad')

# %%
adata.obsm['X_scVI'] = model.get_latent_representation()

# %%
adata.obsm['X_scVI'].shape
# Out:
# (51462, 60)

# %%
sc.pp.neighbors(adata, use_rep = 'X_scVI')

# %%
sc.tl.leiden(adata, resolution = 3, key_added = 'overcluster')

# %%
sc.tl.umap(adata)

# %%
adata.layers['counts'] = adata.X.copy()

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
adata.write_h5ad('temp.h5ad')

# %%
adata.obs['low_major'] = adata.obs.groupby('overcluster')['low_label'].transform(lambda x: x.mode()[0])

# %%
sc.pl.umap(adata, color = ['low_major'], s = 5)
# Out:
# ... storing 'low_major' as categorical

# %%
adata.obs['predicted_major'] = adata.obs.groupby('overcluster')['predicted'].transform(lambda x: x.mode()[0])

sc.pl.umap(adata, color = ['predicted_major'], legend_loc = 'on data', s = 5)
